# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk import pos_tag
from nltk.sentiment import SentimentIntensityAnalyzer
import spacy

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('vader_lexicon')
nltk.download('punkt_tab')

nlp = spacy.load("en_core_web_sm")

text = """I was planning my vacation for several weeks, and I had been waiting eagerly for my semester break to begin. When the time finally arrived, I was traveling to the mountains while the sun was rising, and the cool breeze was blowing gently around me. The weather had been changing slowly, but it had remained pleasant throughout my stay. I was staying in a small hillside cottage that had been built near a forest, and every morning I was waking up to the sound of birds that had been singing since dawn.

During the day, I was exploring nearby trails, and I was capturing photographs of landscapes that had been untouched for years. I was enjoying local food that had been prepared using traditional methods, and I was talking to villagers who had lived there for generations. The peaceful environment had been calming my mind, and it had helped me forget the stress that I had been carrying for months.

By the end of the vacation, I was realizing how much the experience had changed me. I had regained my energy, and I was feeling refreshed as I was returning home with memories that had been created slowly and meaningfully."""

tokens = word_tokenize(text)
print("Tokens:", tokens)

ps = PorterStemmer()
stems = [ps.stem(word) for word in tokens]
print("\nStemming:", stems)

doc = nlp(text)
lemmas = [token.lemma_ for token in doc]
print("\nLemmatization:", lemmas)

pos_tags = pos_tag(tokens)
print("\nPOS Tags:", pos_tags)

sia = SentimentIntensityAnalyzer()
sentiment = sia.polarity_scores(text)
print("\nSentiment Analysis:", sentiment)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Tokens: ['I', 'was', 'planning', 'my', 'vacation', 'for', 'several', 'weeks', ',', 'and', 'I', 'had', 'been', 'waiting', 'eagerly', 'for', 'my', 'semester', 'break', 'to', 'begin', '.', 'When', 'the', 'time', 'finally', 'arrived', ',', 'I', 'was', 'traveling', 'to', 'the', 'mountains', 'while', 'the', 'sun', 'was', 'rising', ',', 'and', 'the', 'cool', 'breeze', 'was', 'blowing', 'gently', 'around', 'me', '.', 'The', 'weather', 'had', 'been', 'changing', 'slowly', ',', 'but', 'it', 'had', 'remained', 'pleasant', 'throughout', 'my', 'stay', '.', 'I', 'was', 'staying', 'in', 'a', 'small', 'hillside', 'cottage', 'that', 'had', 'been', 'built', 'near', 'a', 'forest', ',', 'and', 'every', 'morning', 'I', 'was', 'waking', 'up', 'to', 'the', 'sound', 'of', 'birds', 'that', 'had', 'been', 'singing', 'since', 'dawn', '.', 'During', 'the', 'day', ',', 'I', 'was', 'exploring', 'nearby', 'trails', ',', 'and', 'I', 'was', 'capturing', 'photographs', 'of', 'landscapes', 'that', 'had', 'been', 'untouched', 'for', 'years', '.', 'I', 'was', 'enjoying', 'local', 'food', 'that', 'had', 'been', 'prepared', 'using', 'traditional', 'methods', ',', 'and', 'I', 'was', 'talking', 'to', 'villagers', 'who', 'had', 'lived', 'there', 'for', 'generations', '.', 'The', 'peaceful', 'environment', 'had', 'been', 'calming', 'my', 'mind', ',', 'and', 'it', 'had', 'helped', 'me', 'forget', 'the', 'stress', 'that', 'I', 'had', 'been', 'carrying', 'for', 'months', '.', 'By', 'the', 'end', 'of', 'the', 'vacation', ',', 'I', 'was', 'realizing', 'how', 'much', 'the', 'experience', 'had', 'changed', 'me', '.', 'I', 'had', 'regained', 'my', 'energy', ',', 'and', 'I', 'was', 'feeling', 'refreshed', 'as', 'I', 'was', 'returning', 'home', 'with', 'memories', 'that', 'had', 'been', 'created', 'slowly', 'and', 'meaningfully', '.']
#
# Stemming: ['i', 'wa', 'plan', 'my', 'vacat', 'for', 'sever', 'week', ',', 'and', 'i', 'had', 'been', 'wait', 'eagerli', 'for', 'my', 'semest', 'break', 'to', 'begin', '.', 'when', 'the', 'time', 'final', 'arriv', ',', 'i', 'wa', 'travel', 'to', 'the', 'mountain', 'while', 'the', 'sun', 'wa', 'rise', ',', 'and', 'the', 'cool', 'breez', 'wa', 'blow', 'gentli', 'around', 'me', '.', 'the', 'weather', 'had', 'been', 'chang', 'slowli', ',', 'but', 'it', 'had', 'remain', 'pleasant', 'throughout', 'my', 'stay', '.', 'i', 'wa', 'stay', 'in', 'a', 'small', 'hillsid', 'cottag', 'that', 'had', 'been', 'built', 'near', 'a', 'forest', ',', 'and', 'everi', 'morn', 'i', 'wa', 'wake', 'up', 'to', 'the', 'sound', 'of', 'bird', 'that', 'had', 'been', 'sing', 'sinc', 'dawn', '.', 'dure', 'the', 'day', ',', 'i', 'wa', 'explor', 'nearbi', 'trail', ',', 'and', 'i', 'wa', 'captur', 'photograph', 'of', 'landscap', 'that', 'had', 'been', 'untouch', 'for', 'year', '.', 'i', 'wa', 'enjoy', 'local', 'food', 'that', 'had', 'been', 'prepar', 'use', 'tradit', 'method', ',', 'and', 'i', 'wa', 'talk', 'to', 'villag', 'who', 'had', 'live', 'there', 'for', 'gener', '.', 'the', 'peac', 'environ', 'had', 'been', 'calm', 'my', 'mind', ',', 'and', 'it', 'had', 'help', 'me', 'forget', 'the', 'stress', 'that', 'i', 'had', 'been', 'carri', 'for', 'month', '.', 'by', 'the', 'end', 'of', 'the', 'vacat', ',', 'i', 'wa', 'realiz', 'how', 'much', 'the', 'experi', 'had', 'chang', 'me', '.', 'i', 'had', 'regain', 'my', 'energi', ',', 'and', 'i', 'wa', 'feel', 'refresh', 'as', 'i', 'wa', 'return', 'home', 'with', 'memori', 'that', 'had', 'been', 'creat', 'slowli', 'and', 'meaning', '.']
#
# Lemmatization: ['I', 'be', 'plan', 'my', 'vacation', 'for', 'several', 'week', ',', 'and', 'I', 'have', 'be', 'wait', 'eagerly', 'for', 'my', 'semester', 'break', 'to', 'begin', '.', 'when', 'the', 'time', 'finally', 'arrive', ',', 'I', 'be', 'travel', 'to', 'the', 'mountain', 'while', 'the', 'sun', 'be', 'rise', ',', 'and', 'the', 'cool', 'breeze', 'be', 'blow', 'gently', 'around', 'I', '.', 'the', 'weather', 'have', 'be', 'change', 'slowly', ',', 'but', 'it', 'have', 'remain', 'pleasant', 'throughout', 'my', 'stay', '.', 'I', 'be', 'stay', 'in', 'a', 'small', 'hillside', 'cottage', 'that', 'have', 'be', 'build', 'near', 'a', 'forest', ',', 'and', 'every', 'morning', 'I', 'be', 'wake', 'up', 'to', 'the', 'sound', 'of', 'bird', 'that', 'have', 'be', 'sing', 'since', 'dawn', '.', '\n\n', 'during', 'the', 'day', ',', 'I', 'be', 'explore', 'nearby', 'trail', ',', 'and', 'I', 'be', 'capture', 'photograph', 'of', 'landscape', 'that', 'have', 'be', 'untouched', 'for', 'year', '.', 'I', 'be', 'enjoy', 'local', 'food', 'that', 'have', 'be', 'prepare', 'use', 'traditional', 'method', ',', 'and', 'I', 'be', 'talk', 'to', 'villager', 'who', 'have', 'live', 'there', 'for', 'generation', '.', 'the', 'peaceful', 'environment', 'have', 'be', 'calm', 'my', 'mind', ',', 'and', 'it', 'have', 'help', 'I', 'forget', 'the', 'stress', 'that', 'I', 'have', 'be', 'carry', 'for', 'month', '.', '\n\n', 'by', 'the', 'end', 'of', 'the', 'vacation', ',', 'I', 'be', 'realize', 'how', 'much', 'the', 'experience', 'have', 'change', 'I', '.', 'I', 'have', 'regain', 'my', 'energy', ',', 'and', 'I', 'be', 'feeling', 'refresh', 'as', 'I', 'be', 'return', 'home', 'with', 'memory', 'that', 'have', 'be', 'create', 'slowly', 'and', 'meaningfully', '.']
#
# POS Tags: [('I', 'PRP'), ('was', 'VBD'), ('planning', 'VBG'), ('my', 'PRP$'), ('vacation', 'NN'), ('for', 'IN'), ('several', 'JJ'), ('weeks', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('had', 'VBD'), ('been', 'VBN'), ('waiting', 'VBG'), ('eagerly', 'RB'), ('for', 'IN'), ('my', 'PRP$'), ('semester', 'NN'), ('break', 'NN'), ('to', 'TO'), ('begin', 'VB'), ('.', '.'), ('When', 'WRB'), ('the', 'DT'), ('time', 'NN'), ('finally', 'RB'), ('arrived', 'VBD'), (',', ','), ('I', 'PRP'), ('was', 'VBD'), ('traveling', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('mountains', 'NNS'), ('while', 'IN'), ('the', 'DT'), ('sun', 'NN'), ('was', 'VBD'), ('rising', 'VBG'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('cool', 'JJ'), ('breeze', 'NN'), ('was', 'VBD'), ('blowing', 'VBG'), ('gently', 'RB'), ('around', 'IN'), ('me', 'PRP'), ('.', '.'), ('The', 'DT'), ('weather', 'NN'), ('had', 'VBD'), ('been', 'VBN'), ('changing', 'VBG'), ('slowly', 'RB'), (',', ','), ('but', 'CC'), ('it', 'PRP'), ('had', 'VBD'), ('remained', 'VBN'), ('pleasant', 'JJ'), ('throughout', 'IN'), ('my', 'PRP$'), ('stay', 'NN'), ('.', '.'), ('I', 'PRP'), ('was', 'VBD'), ('staying', 'VBG'), ('in', 'IN'), ('a', 'DT'), ('small', 'JJ'), ('hillside', 'NN'), ('cottage', 'NN'), ('that', 'WDT'), ('had', 'VBD'), ('been', 'VBN'), ('built', 'VBN'), ('near', 'IN'), ('a', 'DT'), ('forest', 'NN'), (',', ','), ('and', 'CC'), ('every', 'DT'), ('morning', 'NN'), ('I', 'PRP'), ('was', 'VBD'), ('waking', 'VBG'), ('up', 'RP'), ('to', 'TO'), ('the', 'DT'), ('sound', 'NN'), ('of', 'IN'), ('birds', 'NNS'), ('that', 'WDT'), ('had', 'VBD'), ('been', 'VBN'), ('singing', 'VBG'), ('since', 'IN'), ('dawn', 'NN'), ('.', '.'), ('During', 'IN'), ('the', 'DT'), ('day', 'NN'), (',', ','), ('I', 'PRP'), ('was', 'VBD'), ('exploring', 'VBG'), ('nearby', 'RB'), ('trails', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('was', 'VBD'), ('capturing', 'VBG'), ('photographs', 'NN'), ('of', 'IN'), ('landscapes', 'NNS'), ('that', 'WDT'), ('had', 'VBD'), ('been', 'VBN'), ('untouched', 'VBN'), ('for', 'IN'), ('years', 'NNS'), ('.', '.'), ('I', 'PRP'), ('was', 'VBD'), ('enjoying', 'VBG'), ('local', 'JJ'), ('food', 'NN'), ('that', 'WDT'), ('had', 'VBD'), ('been', 'VBN'), ('prepared', 'VBN'), ('using', 'VBG'), ('traditional', 'JJ'), ('methods', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('was', 'VBD'), ('talking', 'VBG'), ('to', 'TO'), ('villagers', 'NNS'), ('who', 'WP'), ('had', 'VBD'), ('lived', 'VBN'), ('there', 'RB'), ('for', 'IN'), ('generations', 'NNS'), ('.', '.'), ('The', 'DT'), ('peaceful', 'JJ'), ('environment', 'NN'), ('had', 'VBD'), ('been', 'VBN'), ('calming', 'VBG'), ('my', 'PRP$'), ('mind', 'NN'), (',', ','), ('and', 'CC'), ('it', 'PRP'), ('had', 'VBD'), ('helped', 'VBN'), ('me', 'PRP'), ('forget', 'VB'), ('the', 'DT'), ('stress', 'NN'), ('that', 'IN'), ('I', 'PRP'), ('had', 'VBD'), ('been', 'VBN'), ('carrying', 'VBG'), ('for', 'IN'), ('months', 'NNS'), ('.', '.'), ('By', 'IN'), ('the', 'DT'), ('end', 'NN'), ('of', 'IN'), ('the', 'DT'), ('vacation', 'NN'), (',', ','), ('I', 'PRP'), ('was', 'VBD'), ('realizing', 'VBG'), ('how', 'WRB'), ('much', 'JJ'), ('the', 'DT'), ('experience', 'NN'), ('had', 'VBD'), ('changed', 'VBN'), ('me', 'PRP'), ('.', '.'), ('I', 'PRP'), ('had', 'VBD'), ('regained', 'VBN'), ('my', 'PRP$'), ('energy', 'NN'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('was', 'VBD'), ('feeling', 'VBG'), ('refreshed', 'VBN'), ('as', 'IN'), ('I', 'PRP'), ('was', 'VBD'), ('returning', 'VBG'), ('home', 'NN'), ('with', 'IN'), ('memories', 'NNS'), ('that', 'WDT'), ('had', 'VBD'), ('been', 'VBN'), ('created', 'VBN'), ('slowly', 'RB'), ('and', 'CC'), ('meaningfully', 'RB'), ('.', '.')]
#
# Sentiment Analysis: {'neg': 0.029, 'neu': 0.82, 'pos': 0.151, 'compound': 0.9737}
